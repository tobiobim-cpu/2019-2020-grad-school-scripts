# %%
from os import access
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from pandas.core import series

# %%
series_obj = Series(np.arange(8), index=['row 1', 'row 2', 'row 3', 'row 4', 'row 5', 'row 6', 'row 7', 'row 8']) ##np.arrange() func creates an array of numbers from 0-7 and index 'row 1' -> 0, 'row 2' -> 1, and 'row 3' -> 2
print(series_obj)
print(series_obj['row 7']) #returns the corresponding value for 'row 7'
print(series_obj[[0, 7]]) #returns the 1st and the 8th array in series_obj dataframe
# Out:
# row 1    0
# row 2    1
# row 3    2
# row 4    3
# row 5    4
# row 6    5
# row 7    6
# row 8    7
# dtype: int32
# 6
# row 1    0
# row 8    7
# dtype: int32

# %%
missing = np.nan
seriess_obj = Series(['row 1', 'row 2', missing, 'row 4', 'row 5', 'row 6', missing, 'row 8'])

IsN = seriess_obj.isnull()
print(IsN)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
np.random.seed(25)
dff_obj = DataFrame(np.random.rand(36).reshape((6, 6)))
dff_obj.loc[3:5, 0] = missing 
dff_obj.loc[1:4, 5] = missing 


print(dff_obj)
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366       NaN
# 2  0.447031  0.585445  0.161985  0.520719  0.326051       NaN
# 3       NaN  0.836375  0.481343  0.516502  0.383048       NaN
# 4       NaN  0.559053  0.034450  0.719930  0.421004       NaN
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
sum_missing =dff_obj.isnull().sum()
print(sum_missing) #Sums the number of missing values in each column
# Out:
# 0    3
# 1    0
# 2    0
# 3    0
# 4    0
# 5    4
# dtype: int64

# %%
No_NaN = dff_obj.dropna()
print(No_NaN) #drops the rows with missing values
# Out:
#           0         1         2         3       4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.4111  0.117376

# %%
address = r'C:\Users\dobimuyiwa\Documents\Exercise Files\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
print(cars.describe())
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
print(cars.sum(), '\n') # for columns
print(cars.sum(axis=1)) #for rows
print(cars.median()) #find the median for each variables
print(cars.mean()) #find the mean for each variables.
# Out:
# car_names    Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...
# mpg                                                      642.9
# cyl                                                        198
# disp                                                    7383.1
# hp                                                        4694
# drat                                                    115.09
# wt                                                     102.952
# qsec                                                    571.16
# vs                                                          14
# am                                                          13
# gear                                                       118
# carb                                                        90
# dtype: object
#
# 0     328.980
# 1     329.795
# 2     259.580
# 3     426.135
# 4     590.310
# 5     385.540
# 6     656.920
# 7     270.980
# 8     299.570
# 9     350.460
# 10    349.660
# 11    510.740
# 12    511.500
# 13    509.850
# 14    728.560
# 15    726.644
# 16    725.695
# 17    213.850
# 18    195.165
# 19    206.955
# 20    273.775
# 21    519.650
# 22    506.085
# 23    646.280
# 24    631.175
# 25    208.215
# 26    272.570
# 27    273.683
# 28    670.690
# 29    379.590
# 30    694.710
# 31    288.890
# dtype: float64
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64
# C:\Users\DOBIMU~1\AppData\Local\Temp/ipykernel_15532/165460510.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(cars.sum(axis=1)) #for rows
# C:\Users\DOBIMU~1\AppData\Local\Temp/ipykernel_15532/165460510.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(cars.median()) #find the median for each variables
# C:\Users\DOBIMU~1\AppData\Local\Temp/ipykernel_15532/165460510.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(cars.mean()) #find the mean for each variables.

# %%
import matplotlib
import pylab as plt

mpg = cars.mpg #isolate the variable 'mpg' from dataset 'cars'
plt.plot(mpg)
plt.title('MPG graph from cars dataset')
plt.show()
print('The index no of the row with max value is:', mpg.idxmax()) # returns the index number of the row with the max value in MPG
# Out:
# The index no of the row with max value is: 19

# %%
print(cars.std()) #returns standard deviation for each of the variables
print(cars.var()) #returns varaiance for each of the variables
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64
# mpg        36.324103
# cyl         3.189516
# disp    15360.799829
# hp       4700.866935
# drat        0.285881
# wt          0.957379
# qsec        3.193166
# vs          0.254032
# am          0.248992
# gear        0.544355
# carb        2.608871
# dtype: float64
# C:\Users\DOBIMU~1\AppData\Local\Temp/ipykernel_13768/1513621841.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(cars.std()) #returns standard deviation for each of the variables
# C:\Users\DOBIMU~1\AppData\Local\Temp/ipykernel_13768/1513621841.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(cars.var()) #returns varaiance for each of the variables

# %%
gear = cars.gear
print(gear.value_counts())
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
cyl = cars.cyl
print(cyl.value_counts())
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
cars_cat = cars[['cyl', 'vs', 'am', 'gear', 'carb']]
cyl_group = cars_cat.groupby('am')
cyl_group.describe()
# Out:
#      cyl                                                 vs            ...  \
#    count      mean       std  min  25%  50%  75%  max count      mean  ...
# am                                                                     ...
# 0   19.0  6.947368  1.544657  4.0  6.0  8.0  8.0  8.0  19.0  0.368421  ...
# 1   13.0  5.076923  1.552500  4.0  4.0  4.0  6.0  8.0  13.0  0.538462  ...
#
#    gear       carb
#     75%  max count      mean       std  min  25%  50%  75%  max
# am
# 0   3.0  4.0  19.0  2.736842  1.147079  1.0  2.0  3.0  4.0  4.0
# 1   5.0  5.0  13.0  2.923077  2.177978  1.0  1.0  2.0  4.0  8.0
#
# [2 rows x 32 columns]

# %%
cars['group'] = pd.Series(cars.cyl, dtype="category")
print(cars['group'])
# Out:
# 0     6
# 1     6
# 2     4
# 3     6
# 4     8
# 5     6
# 6     8
# 7     4
# 8     4
# 9     6
# 10    6
# 11    8
# 12    8
# 13    8
# 14    8
# 15    8
# 16    8
# 17    4
# 18    4
# 19    4
# 20    4
# 21    8
# 22    8
# 23    8
# 24    8
# 25    4
# 26    4
# 27    4
# 28    8
# 29    6
# 30    8
# 31    4
# Name: group, dtype: category
# Categories (3, int64): [4, 6, 8]

# %%
cars['group'].dtypes
print(cars['group'].value_counts())
# Out:
# 8    14
# 4    11
# 6     7
# Name: group, dtype: int64

# %%
ct =pd.crosstab(cars['cyl'], cars['vs'])
print(ct)
# Out:
# vs    0   1
# cyl
# 4     1  10
# 6     3   4
# 8    14   0

# %%
cars.index = cars.car_names
print(cars.head(15))
# Out:
#                              car_names   mpg  cyl   disp   hp  drat     wt  \
# car_names
# Mazda RX4                    Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag            Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                  Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive          Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                        Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                  Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                    Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                      Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                      Merc 280  19.2    6  167.6  123  3.92  3.440
# Merc 280C                    Merc 280C  17.8    6  167.6  123  3.92  3.440
# Merc 450SE                  Merc 450SE  16.4    8  275.8  180  3.07  4.070
# Merc 450SL                  Merc 450SL  17.3    8  275.8  180  3.07  3.730
# Merc 450SLC                Merc 450SLC  15.2    8  275.8  180  3.07  3.780
# Cadillac Fleetwood  Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250
#
#                      qsec  vs  am  gear  carb group
# car_names
# Mazda RX4           16.46   0   1     4     4     6
# Mazda RX4 Wag       17.02   0   1     4     4     6
# Datsun 710          18.61   1   1     4     1     4
# Hornet 4 Drive      19.44   1   0     3     1     6
# Hornet Sportabout   17.02   0   0     3     2     8
# Valiant             20.22   1   0     3     1     6
# Duster 360          15.84   0   0     3     4     8
# Merc 240D           20.00   1   0     4     2     4
# Merc 230            22.90   1   0     4     2     4
# Merc 280            18.30   1   0     4     4     6
# Merc 280C           18.90   1   0     4     4     6
# Merc 450SE          17.40   0   0     3     3     8
# Merc 450SL          17.60   0   0     3     3     8
# Merc 450SLC         18.00   0   0     3     3     8
# Cadillac Fleetwood  17.98   0   0     3     4     8

# %%
#groupby method
cars_cat = cars[['cyl', 'vs', 'am', 'gear', 'carb']]
gears_group = cars_cat.groupby('gear')
print(gears_group.describe())
# Out:
#        cyl                                                 vs            ...  \
#      count      mean       std  min  25%  50%  75%  max count      mean  ...
# gear                                                                     ...
# 3     15.0  7.466667  1.187234  4.0  8.0  8.0  8.0  8.0  15.0  0.200000  ...
# 4     12.0  4.666667  0.984732  4.0  4.0  4.0  6.0  6.0  12.0  0.833333  ...
# 5      5.0  6.000000  2.000000  4.0  4.0  6.0  8.0  8.0   5.0  0.200000  ...
#
#        am       carb
#       75%  max count      mean       std  min  25%  50%  75%  max
# gear
# 3     0.0  0.0  15.0  2.666667  1.175139  1.0  2.0  3.0  4.0  4.0
# 4     1.0  1.0  12.0  2.333333  1.302678  1.0  1.0  2.0  4.0  4.0
# 5     1.0  1.0   5.0  4.400000  2.607681  2.0  2.0  4.0  6.0  8.0
#
# [3 rows x 32 columns]

# %%
y = cars[['mpg', 'hp']]
corr =y.corr() 
print(corr) ##it gives the summary of the correlation values in "x"
# Out:
#           mpg        hp
# mpg  1.000000 -0.776168
# hp  -0.776168  1.000000

# %%
x = cars[['mpg', 'hp', 'qsec', 'wt', 'cyl', 'vs', 'am', 'gear']]

corr =x.corr() 
print(corr)
# Out:
#            mpg        hp      qsec        wt       cyl        vs        am  \
# mpg   1.000000 -0.776168  0.418684 -0.867659 -0.852162  0.664039  0.599832
# hp   -0.776168  1.000000 -0.708223  0.658748  0.832447 -0.723097 -0.243204
# qsec  0.418684 -0.708223  1.000000 -0.174716 -0.591242  0.744535 -0.229861
# wt   -0.867659  0.658748 -0.174716  1.000000  0.782496 -0.554916 -0.692495
# cyl  -0.852162  0.832447 -0.591242  0.782496  1.000000 -0.810812 -0.522607
# vs    0.664039 -0.723097  0.744535 -0.554916 -0.810812  1.000000  0.168345
# am    0.599832 -0.243204 -0.229861 -0.692495 -0.522607  0.168345  1.000000
# gear  0.480285 -0.125704 -0.212682 -0.583287 -0.492687  0.206023  0.794059
#
#           gear
# mpg   0.480285
# hp   -0.125704
# qsec -0.212682
# wt   -0.583287
# cyl  -0.492687
# vs    0.206023
# am    0.794059
# gear  1.000000

# %%
#print(mpg.describe(), '\n')
mpg_matrix = mpg.values.reshape(-1,1)
print(mpg_matrix)
# Out:
# [[21. ]
#  [21. ]
#  [22.8]
#  [21.4]
#  [18.7]
#  [18.1]
#  [14.3]
#  [24.4]
#  [22.8]
#  [19.2]
#  [17.8]
#  [16.4]
#  [17.3]
#  [15.2]
#  [10.4]
#  [10.4]
#  [14.7]
#  [32.4]
#  [30.4]
#  [33.9]
#  [21.5]
#  [15.5]
#  [15.2]
#  [13.3]
#  [19.2]
#  [27.3]
#  [26. ]
#  [30.4]
#  [15.8]
#  [19.7]
#  [15. ]
#  [21.4]]

# %%
from sklearn import preprocessing
from sklearn.preprocessing import scale


scaled = preprocessing.MinMaxScaler()
scaled_mpg = scaled.fit_transform(mpg_matrix)
print(scaled_mpg)
# Out:
# [[0.45106383]
#  [0.45106383]
#  [0.52765957]
#  [0.46808511]
#  [0.35319149]
#  [0.32765957]
#  [0.16595745]
#  [0.59574468]
#  [0.52765957]
#  [0.37446809]
#  [0.31489362]
#  [0.25531915]
#  [0.29361702]
#  [0.20425532]
#  [0.        ]
#  [0.        ]
#  [0.18297872]
#  [0.93617021]
#  [0.85106383]
#  [1.        ]
#  [0.47234043]
#  [0.21702128]
#  [0.20425532]
#  [0.12340426]
#  [0.37446809]
#  [0.71914894]
#  [0.66382979]
#  [0.85106383]
#  [0.22978723]
#  [0.39574468]
#  [0.19574468]
#  [0.46808511]]

# %%
scaled = preprocessing.MinMaxScaler(feature_range=(0,10))

unstandard_mpg = scale(mpg, axis=0, with_mean=False, with_std=False)

plt.plot(unstandard_mpg)
plt.show()

# %%
standard_mpg = scale(mpg) ##Standadized now! Mean has been centered to zero and the var now has Normal dist.
plt.plot(standard_mpg)
plt.show()

# %%
address = r'C:\Users\dobimuyiwa\Documents\Exercise Files\Ex_Files_Python_Data_Science_EssT_Pt_1\Exercise Files\Data\iris.data.csv'
iris = pd.read_csv(address)
iris.columns=['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Species']

X = iris.iloc[:,0:4].values ## This represent the features/predictive variable (first 5 colums)
Y = iris.iloc[:,0:4].values  ## Target variable. prints up to first 5 rows
print(iris[0:5], '\n') ## This is the same as -> print(iris.head())
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           4.9          3.0           1.4          0.2  setosa
# 1           4.7          3.2           1.3          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
iris.boxplot(return_type='dict')
plt.plot()
plt.show()
